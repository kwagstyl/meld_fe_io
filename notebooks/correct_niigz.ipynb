# %%
## correct nii.gz files that are not really zipped

# correct zip in .nii
import gzip
import shutil
import glob
import sys
import subprocess as sub

def check_gzip(file):
    # ensure file are gzip, or gzip
    if '.nii.gz' in file:
        try:
            with gzip.open(file, 'rb') as f:
                data = f.read(10)  # Read the first 10 bytes (adjust as needed)
        except OSError as e:
            if "Not a gzipped file" in str(e):
                print(f"ERROR: The file '{file}' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun")
                print('Zipp the file ')
                unzip_file = file.split('.nii.gz')[0] + '.nii'
                shutil.move(file, unzip_file)
                command = format(f'gzip {unzip_file}')
                sub.check_call(command, shell=True)
            elif "No such file" in str(e):
                print(f"ERROR: The file '{file}' was not found.")
                sys.exit()
            else:
                print(f"ERROR: An error occurred: {e}")
                sys.exit()
            
    else:
        try:
            with gzip.open(file, 'rb') as f:
                data = f.read(10)  # Read the first 10 bytes (adjust as needed)
            print(f"ERROR: The file '{file}' is compressed using gzip but does not have the right suffix '.nii.gz' ")
            sys.exit()
        except OSError as e:
            if "Not a gzipped file" in str(e):
                command = format(f'gzip {file}')
                sub.check_call(command, shell=True)
                file = file+'.gz'
    return file

# files = glob.glob('/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H/MELD_BIDS/*/*/*.nii.gz')
files = glob.glob('/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/*/*/*mask*.nii.gz')
for file in files:
    print(file)
    check_gzip(file)
# Out:
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0124/anat/sub-MELDH11P0124_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0124/anat/sub-MELDH11P0124_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0144/anat/sub-MELDH11P0144_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0144/anat/sub-MELDH11P0144_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0115/anat/sub-MELDH11P0115_3T_lesion_mask.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0139/anat/sub-MELDH11P0139_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0139/anat/sub-MELDH11P0139_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0145/anat/sub-MELDH11P0145_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0145/anat/sub-MELDH11P0145_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0153/anat/sub-MELDH11P0153_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0153/anat/sub-MELDH11P0153_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0155/anat/sub-MELDH11P0155_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0155/anat/sub-MELDH11P0155_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0157/anat/sub-MELDH11P0157_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0157/anat/sub-MELDH11P0157_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0109/anat/sub-MELDH11P0109_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0109/anat/sub-MELDH11P0109_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0125/anat/sub-MELDH11P0125_3T_lesion_mask.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0150/anat/sub-MELDH11P0150_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0150/anat/sub-MELDH11P0150_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0121/anat/sub-MELDH11P0121_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0121/anat/sub-MELDH11P0121_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0134/anat/sub-MELDH11P0134_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0134/anat/sub-MELDH11P0134_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0148/anat/sub-MELDH11P0148_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0148/anat/sub-MELDH11P0148_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0161/anat/sub-MELDH11P0161_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0161/anat/sub-MELDH11P0161_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0137/anat/sub-MELDH11P0137_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0137/anat/sub-MELDH11P0137_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0116/anat/sub-MELDH11P0116_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0116/anat/sub-MELDH11P0116_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0136/anat/sub-MELDH11P0136_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0136/anat/sub-MELDH11P0136_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0158/anat/sub-MELDH11P0158_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0158/anat/sub-MELDH11P0158_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0135/anat/sub-MELDH11P0135_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0135/anat/sub-MELDH11P0135_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0110/anat/sub-MELDH11P0110_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0110/anat/sub-MELDH11P0110_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0165/anat/sub-MELDH11P0165_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0165/anat/sub-MELDH11P0165_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0156/anat/sub-MELDH11P0156_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0156/anat/sub-MELDH11P0156_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0164/anat/sub-MELDH11P0164_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0164/anat/sub-MELDH11P0164_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0163/anat/sub-MELDH11P0163_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0163/anat/sub-MELDH11P0163_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0120/anat/sub-MELDH11P0120_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0120/anat/sub-MELDH11P0120_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0112/anat/sub-MELDH11P0112_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0112/anat/sub-MELDH11P0112_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0123/anat/sub-MELDH11P0123_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0123/anat/sub-MELDH11P0123_3T_lesion_mask.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P0119/anat/sub-MELDH11P0119_3T_lesion_mask.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H11/MELD_BIDS/sub-MELDH11P
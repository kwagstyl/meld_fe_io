# %%
## correct nii.gz files that are not really zipped

# correct zip in .nii
import gzip
import shutil
import glob
import sys
import subprocess as sub

def check_gzip(file):
    # ensure file are gzip, or gzip
    if '.nii.gz' in file:
        try:
            with gzip.open(file, 'rb') as f:
                data = f.read(10)  # Read the first 10 bytes (adjust as needed)
        except OSError as e:
            if "Not a gzipped file" in str(e):
                print(f"ERROR: The file '{file}' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun")
                print('Zipp the file ')
                unzip_file = file.split('.nii.gz')[0] + '.nii'
                shutil.move(file, unzip_file)
                command = format(f'gzip {unzip_file}')
                sub.check_call(command, shell=True)
            elif "No such file" in str(e):
                print(f"ERROR: The file '{file}' was not found.")
                sys.exit()
            else:
                print(f"ERROR: An error occurred: {e}")
                sys.exit()
            
    else:
        try:
            with gzip.open(file, 'rb') as f:
                data = f.read(10)  # Read the first 10 bytes (adjust as needed)
            print(f"ERROR: The file '{file}' is compressed using gzip but does not have the right suffix '.nii.gz' ")
            sys.exit()
        except OSError as e:
            if "Not a gzipped file" in str(e):
                command = format(f'gzip {file}')
                sub.check_call(command, shell=True)
                file = file+'.gz'
    return file

files = glob.glob('/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/*/*/*.nii.gz')

for file in files:
    print(file)
    check_gzip(file)
# Out:
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0184/anat/sub-MELDH21P0184_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0184/anat/sub-MELDH21P0184_3T_postop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0184/anat/sub-MELDH21P0184_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0212/anat/sub-MELDH21P0212_3T_postop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0212/anat/sub-MELDH21P0212_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0212/anat/sub-MELDH21P0212_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0078/anat/sub-MELDH21P0078_3T_postop_T1w.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0078/anat/sub-MELDH21P0078_3T_postop_T1w.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0078/anat/sub-MELDH21P0078_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0078/anat/sub-MELDH21P0078_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0036/anat/sub-MELDH21P0036_15T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0036/anat/sub-MELDH21P0036_15T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0036/anat/sub-MELDH21P0036_15T_postop_T1w.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0036/anat/sub-MELDH21P0036_15T_postop_T1w.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0082/anat/sub-MELDH21P0082_3T_postop_T1w.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0082/anat/sub-MELDH21P0082_3T_postop_T1w.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0082/anat/sub-MELDH21P0082_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0082/anat/sub-MELDH21P0082_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0058/anat/sub-MELDH21P0058_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0058/anat/sub-MELDH21P0058_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0058/anat/sub-MELDH21P0058_3T_postop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0085/anat/sub-MELDH21P0085_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0085/anat/sub-MELDH21P0085_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0085/anat/sub-MELDH21P0085_3T_postop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0162/anat/sub-MELDH21P0162_3T_postop_T1w.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0162/anat/sub-MELDH21P0162_3T_postop_T1w.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0162/anat/sub-MELDH21P0162_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0162/anat/sub-MELDH21P0162_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0048/anat/sub-MELDH21P0048_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0048/anat/sub-MELDH21P0048_3T_postop_T1w.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0048/anat/sub-MELDH21P0048_3T_postop_T1w.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0048/anat/sub-MELDH21P0048_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0061/anat/sub-MELDH21P0061_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0061/anat/sub-MELDH21P0061_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0061/anat/sub-MELDH21P0061_3T_postop_T1w.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0061/anat/sub-MELDH21P0061_3T_postop_T1w.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0073/anat/sub-MELDH21P0073_3T_postop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0073/anat/sub-MELDH21P0073_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0073/anat/sub-MELDH21P0073_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0020/anat/sub-MELDH21P0020_3T_postop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0020/anat/sub-MELDH21P0020_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0020/anat/sub-MELDH21P0020_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0049/anat/sub-MELDH21P0049_15T_postop_T1w.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0049/anat/sub-MELDH21P0049_15T_postop_T1w.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0049/anat/sub-MELDH21P0049_15T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0049/anat/sub-MELDH21P0049_15T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0056/anat/sub-MELDH21P0056_3T_postop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0056/anat/sub-MELDH21P0056_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0056/anat/sub-MELDH21P0056_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0065/anat/sub-MELDH21P0065_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0065/anat/sub-MELDH21P0065_3T_preop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0065/anat/sub-MELDH21P0065_3T_postop_T1w.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0075/anat/sub-MELDH21P0075_3T_lesion_MASK.nii.gz
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0075/anat/sub-MELDH21P0075_3T_postop_T1w.nii.gz
# ERROR: The file '/home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P0075/anat/sub-MELDH21P0075_3T_postop_T1w.nii.gz' has the suffix '.nii.gz. but is not genuinely compressed using gzip. Check that you have the right format and rerun
# Zipp the file
# /home/mathilde/Documents/RDS/MELD_FE/DATA/MELD_H21/MELD_BIDS/sub-MELDH21P